# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
data=pd.read_csv("mini project breast cancer.csv",na_values='Missing')
data
# Out:
#        Age_At_The_Time_Of_Mammography   Radiologists_Assessment  \
# 0                                  62                  Negative
# 1                                  65                  Negative
# 2                                  69  Needs additional imaging
# 3                                  64           Benign findings
# 4                                  63           Probably benign
# ...                               ...                       ...
# 39993                              80                  Negative
# 39994                              78                  Negative
# 39995                              77                  Negative
# 39996                              66                  Negative
# 39997                              61                  Negative
#
#        Is_Binary_Indicator_Of_Cancer_Diagnosis  \
# 0                                        False
# 1                                        False
# 2                                        False
# ...

# %%
data.set_index("Patients_Study_ID")
# Out:
#                    Age_At_The_Time_Of_Mammography   Radiologists_Assessment  \
# Patients_Study_ID
# 1                                              62                  Negative
# 2                                              65                  Negative
# 3                                              69  Needs additional imaging
# 4                                              64           Benign findings
# 5                                              63           Probably benign
# ...                                           ...                       ...
# 36711                                          80                  Negative
# 36712                                          78                  Negative
# 36712                                          77                  Negative
# 36713                                          66                  Negative
# 36714                                          61                  Negative
#
# ...

# %%
data.isnull().any()
# Out:
# Age_At_The_Time_Of_Mammography             False
# Radiologists_Assessment                    False
# Is_Binary_Indicator_Of_Cancer_Diagnosis    False
# Comparison_Mammogram_From_Mammography       True
# Patients_BI_RADS_Breast_Density            False
# Family_History_Of_Breast_Cancer             True
# Current_Use_Of_Hormone_Therapy              True
# Binary_Indicator                            True
# History_Of_Breast_Biopsy                    True
# Is_Film_Or_Digital_Mammogram               False
# Cancer_Type                                False
# Body_Mass_Index                             True
# Patients_Study_ID                          False
# dtype: bool

# %%
# a=data1["Body_Mass_Index"].mean()
# data1["Body_Mass_Index"].fillna(a,inplace=True)

# %%
# data.fillna(method="bfill")
data.bfill
# Out:
# <bound method DataFrame.bfill of        Age_At_The_Time_Of_Mammography   Radiologists_Assessment  \
# 0                                  62                  Negative
# 1                                  65                  Negative
# 2                                  69  Needs additional imaging
# 3                                  64           Benign findings
# 4                                  63           Probably benign
# ...                               ...                       ...
# 39993                              80                  Negative
# 39994                              78                  Negative
# 39995                              77                  Negative
# 39996                              66                  Negative
# 39997                              61                  Negative
#
#        Is_Binary_Indicator_Of_Cancer_Diagnosis  \
# 0                                        False
# 1                                        False
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
Radiologists_Assessment=label.fit_transform(data["Radiologists_Assessment"])
Is_Binary_Indicator_Of_Cancer_Diagnosis=label.fit_transform(data["Is_Binary_Indicator_Of_Cancer_Diagnosis"])
Comparison_Mammogram_From_Mammography=label.fit_transform(data["Comparison_Mammogram_From_Mammography"])
Patients_BI_RADS_Breast_Density=label.fit_transform(data["Patients_BI_RADS_Breast_Density"])
Family_History_Of_Breast_Cancer=label.fit_transform(data["Family_History_Of_Breast_Cancer"])
Current_Use_Of_Hormone_Therapy=label.fit_transform(data["Current_Use_Of_Hormone_Therapy"])
Binary_Indicator=label.fit_transform(data["Binary_Indicator"])
History_Of_Breast_Biopsy=label.fit_transform(data["History_Of_Breast_Biopsy"])
Is_Film_Or_Digital_Mammogram=label.fit_transform(data["Is_Film_Or_Digital_Mammogram"])
Cancer_Type=label.fit_transform(data["Cancer_Type"])

# %%
data["Radiologists_Assessment"]=Radiologists_Assessment
data["Is_Binary_Indicator_Of_Cancer_Diagnosis"]=Is_Binary_Indicator_Of_Cancer_Diagnosis
data["Comparison_Mammogram_From_Mammography"]=Comparison_Mammogram_From_Mammography
data["Patients_BI_RADS_Breast_Density"]=Patients_BI_RADS_Breast_Density
data["Family_History_Of_Breast_Cancer"]=Family_History_Of_Breast_Cancer
data["Current_Use_Of_Hormone_Therapy"]=Current_Use_Of_Hormone_Therapy
data["Binary_Indicator"]=Binary_Indicator
data["History_Of_Breast_Biopsy"]=History_Of_Breast_Biopsy
data["Is_Film_Or_Digital_Mammogram"]=Is_Film_Or_Digital_Mammogram
data["Cancer_Type"]=Cancer_Type

# %%
# data["Body_Mass_Index"]=data["Body_Mass_Index"].replace("Missing",25.54)

# %%
data.isnull().any()
# Out:
# Age_At_The_Time_Of_Mammography             False
# Radiologists_Assessment                    False
# Is_Binary_Indicator_Of_Cancer_Diagnosis    False
# Comparison_Mammogram_From_Mammography      False
# Patients_BI_RADS_Breast_Density            False
# Family_History_Of_Breast_Cancer            False
# Current_Use_Of_Hormone_Therapy             False
# Binary_Indicator                           False
# History_Of_Breast_Biopsy                   False
# Is_Film_Or_Digital_Mammogram               False
# Cancer_Type                                False
# Body_Mass_Index                             True
# Patients_Study_ID                          False
# dtype: bool

# %%
data
# Out:
#        Age_At_The_Time_Of_Mammography  Radiologists_Assessment  \
# 0                                  62                        3
# 1                                  65                        3
# 2                                  69                        2
# 3                                  64                        0
# 4                                  63                        4
# ...                               ...                      ...
# 39993                              80                        3
# 39994                              78                        3
# 39995                              77                        3
# 39996                              66                        3
# 39997                              61                        3
#
#        Is_Binary_Indicator_Of_Cancer_Diagnosis  \
# 0                                            0
# 1                                            0
# 2                                            0
# ...

# %%
a=data["Body_Mass_Index"].mean()
data["Body_Mass_Index"].fillna(a,inplace=True)

# %%
data.isnull().any()
# Out:
# Age_At_The_Time_Of_Mammography             False
# Radiologists_Assessment                    False
# Is_Binary_Indicator_Of_Cancer_Diagnosis    False
# Comparison_Mammogram_From_Mammography      False
# Patients_BI_RADS_Breast_Density            False
# Family_History_Of_Breast_Cancer            False
# Current_Use_Of_Hormone_Therapy             False
# Binary_Indicator                           False
# History_Of_Breast_Biopsy                   False
# Is_Film_Or_Digital_Mammogram               False
# Cancer_Type                                False
# Body_Mass_Index                            False
# Patients_Study_ID                          False
# dtype: bool

# %%
data
# Out:
#        Age_At_The_Time_Of_Mammography  Radiologists_Assessment  \
# 0                                  62                        3
# 1                                  65                        3
# 2                                  69                        2
# 3                                  64                        0
# 4                                  63                        4
# ...                               ...                      ...
# 39993                              80                        3
# 39994                              78                        3
# 39995                              77                        3
# 39996                              66                        3
# 39997                              61                        3
#
#        Is_Binary_Indicator_Of_Cancer_Diagnosis  \
# 0                                            0
# 1                                            0
# 2                                            0
# ...

# %%
x=data.drop(["Radiologists_Assessment"],axis=1)
y=data["Radiologists_Assessment"]

# %%
result=[]
models={'logistic':LogisticRegression(),'decision':DecisionTreeClassifier(),'random':RandomForestClassifier()}
for i in models:
    model=models[i]
    scores=cross_val_score(model,x,y,cv=5)
    a=(i,scores.mean())
    result.append(a)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
result
# Out:
# [('logistic', 0.6508075415676959),
#  ('decision', 0.46617518752344045),
#  ('random', 0.5809305225653206)]

# %%
models1={'gaussian':GaussianNB(),'bernoulli':BernoulliNB(),'multinomial':MultinomialNB()}
for i in models1:
    model=models1[i]
    scores=cross_val_score(model,x,y,cv=5)
    b=(i,scores.mean())
    result.append(b)

# %%
result
# Out:
# [('logistic', 0.6508075415676959),
#  ('decision', 0.46617518752344045),
#  ('random', 0.5809305225653206),
#  ('gaussian', 0.6493823415426928),
#  ('bernoulli', 0.6534826697087136),
#  ('multinomial', 0.3500705838229779)]

# %%
f
# result.append(d)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
